# %% [markdown]
# <a href="https://colab.research.google.com/github/Deekshapoornashri25/python5731/blob/master/computational_deeksha.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tweepy as tw
import pandas as pd

consumer_key = 'qWaI6kizU7SAcRNc6EnnoNChq'
consumer_secret = 'xumE7NgIZMiLCUXFeEl0pr3zhsuqdLvOPB0tG94HBQ8PgP2vsK'
access_token = '2747565082-8g1OYC9aFI4NxRInAV5ArxV1te4V6alDLHlQuNn'
access_token_secret = 'rDMmFApw3H5vL5KqVRxwRKdmJCkRdmrqjG8CCfmVroNKV'

auth = tw.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tw.API(auth,wait_on_rate_limit=True)

time=[]
text=[]


for tweet in tw.Cursor(api.search,q="Covid19 vaccine  2020 election",lang="en",since="2020-09-01",until="2020-10-30").items(2300):
  time.append(tweet.created_at)
  text.append(tweet.text)
covid_election_tweets=pd.DataFrame({'tweets':text,'created':time})
covid_election_tweets.to_csv('covid_election.csv')
covid_election_tweets
# Out:
#                                                tweets             created
# 0   RT @TheQuint: Opinion | "#BJP’s move to use th... 2020-10-29 15:18:21
# 1   RT @TheQuint: Opinion | "#BJP’s move to use th... 2020-10-29 05:45:20
# 2   RT @TheQuint: Opinion | "#BJP’s move to use th... 2020-10-29 03:58:48
# 3   RT @TheQuint: Opinion | "#BJP’s move to use th... 2020-10-29 02:33:42
# 4   Opinion | "#BJP’s move to use the pandemic for... 2020-10-29 01:00:01
# 5   So much for approving a #COVID19 vaccine prior... 2020-10-28 22:31:20
# 6   #TrumpIsAMoron #TrumpRallyOmaha\n#COVID19 #vot... 2020-10-28 17:33:30
# 7   RT @TheQuint: #Opinion | "#Bihar verdict on 10... 2020-10-28 10:55:22
# 8   #Opinion | "#Bihar verdict on 10 November may ... 2020-10-28 10:50:56
# 9   RT @GoyenM: Thank you, @EricTopol, for using y... 2020-10-28 06:05:54
# 10  LET'S PRAY AND CROSS OUR FINGERS. \n\nPfizer e... 2020-10-28 01:53:57
# 11  No vaccine before Election Day.\n\nWhich is pr... 2020-10-28 01:49:53
# 12  Pfizer CEO All but Rules Out #COVID19 Vaccine ... 2020-10-28 00:00:01
# 13  @Economesteter The announcement, by Dr. @Alber... 2020-10-27 21:00:32
# 14  RT @denio_vale: @AlbertBourla The announcement... 2020-10-27 20:55:08
# 15  @AlbertBourla The announcement, by Dr. @Albert... 2020-10-27 20:55:00
# 16  RT @denio_vale: @AlbertBourla @BioNTech_Group ... 2020-10-27 20:53:19
# 17  @AlbertBourla @BioNTech_Group The announcement... 2020-10-27 20:53:13
# 18  As awful as this sounds, this Covid19 surge is... 2020-10-27 20:46:52
